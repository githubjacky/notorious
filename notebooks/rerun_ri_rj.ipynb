# %%
import os
os.chdir('..')

# %%
import pandas as pd

from src.data.utils import merge_all_gtab_res

# %%
df_sum = merge_all_gtab_res(adjust_method = 'sum', write = False)
df_sum
# Out:
#                 predator  predator_id   2016_01   2016_02   2016_03   2016_04  \
# 0           Sean Hannity            1  1.390756  1.622549  1.738445  1.738445
# 1           Eric Bolling            2  0.000000  0.000000  0.000000  0.000000
# 2          Charles Payne            3  0.157143  0.128571  0.142857  0.128571
# 3          Harry Knowles            4  0.110000  0.060000  0.050000  0.040000
# 4        Lockhart Steele            5  0.010000  0.010000  0.010000  0.000000
# ..                   ...          ...       ...       ...       ...       ...
# 82          Calvin Smyre           83  0.012920  0.000000  0.000000  0.000000
# 83       Francisco Ayala           84  0.190000  0.210000  0.130000  0.160000
# 84  Roland G. Fryer, Jr.           85  0.005258  0.005736  0.002868  0.000000
# 85        George Tyndall           86  0.000000  0.020000  0.010000  0.010000
# 86      William Strampel           87  0.000000  0.010000  0.010000  0.010000
#
# ...

# %%
df_mean = merge_all_gtab_res(adjust_method = 'mean', write = False)
df_mean
# Out:
#                 predator  predator_id   2016_01   2016_02   2016_03   2016_04  \
# 0           Sean Hannity            1  0.278151  0.405637  0.434611  0.434611
# 1           Eric Bolling            2  0.000000  0.000000  0.000000  0.000000
# 2          Charles Payne            3  0.031429  0.032143  0.035714  0.032143
# 3          Harry Knowles            4  0.022000  0.015000  0.012500  0.010000
# 4        Lockhart Steele            5  0.002000  0.002500  0.002500  0.000000
# ..                   ...          ...       ...       ...       ...       ...
# 82          Calvin Smyre           83  0.002584  0.000000  0.000000  0.000000
# 83       Francisco Ayala           84  0.038000  0.052500  0.032500  0.040000
# 84  Roland G. Fryer, Jr.           85  0.001052  0.001434  0.000717  0.000000
# 85        George Tyndall           86  0.000000  0.005000  0.002500  0.002500
# 86      William Strampel           87  0.000000  0.002500  0.002500  0.002500
#
# ...

# %%
df_ri = pd.read_excel('data/raw/victim_list_01252023.xlsx', sheet_name="Ri")
df_ri
# Out:
#                 predator  predator_id  2016-01-01 00:00:00  \
# 0           Sean Hannity            1             0.857143
# 1           Eric Bolling            2             0.083333
# 2          Charles Payne            3             0.080000
# 3          Harry Knowles            4             0.060000
# 4        Lockhart Steele            5             0.007488
# ..                   ...          ...                  ...
# 82          Calvin Smyre           83             0.003744
# 83       Francisco Ayala           84             0.120000
# 84  Roland G. Fryer, Jr.           85             0.004992
# 85        George Tyndall           86             0.010000
# 86      William Strampel           87             0.000000
#
#     2016-02-01 00:00:00  2016-03-01 00:00:00  2016-04-01 00:00:00  \
# 0              0.928571             1.071429             1.071429
# 1              0.083333             0.250000             0.166667
# ...

# %%
df_victim_sum = merge_all_gtab_res(
    input_dir = 'data/gtab_res/victim/original/',
    output_data_path = 'data/processed/victim_list_01252023.xlsx',
    adjust_method = 'sum',
    write = True
)

df_victim_sum
# Out:
#                   victim  victim_id   2016_01   2016_02   2016_03   2016_04  \
# 0       Debbie Schlussel          1  0.026316  0.052632  0.052632  0.000000
# 1       Caroline Heldman          2  0.000000  0.021505  0.010753  0.021505
# 2    Scottie Nell Hughes          3  0.062500  0.137500  0.187500  1.250000
# 3          Jasmine Baker          4  0.023256  0.010336  0.027132  0.021964
# 4        Eden Rohatensky          5  0.003876  0.007752  0.006460  0.027132
# ..                   ...        ...       ...       ...       ...       ...
# 190     Michelle Herrera        191  0.031008  0.045220  0.052972  0.036176
# 191       Naomi R. Shatz        192       NaN       NaN       NaN       NaN
# 192           Dana Loewy        193  0.003346  0.000000  0.002390  0.000000
# 193                 Heil        194  5.592593  4.574074  4.722222  4.203704
# 194       Nicole Eastman        195  0.010039  0.005736  0.008127  0.004780
#
# ...

# %%
df_victim_mean = merge_all_gtab_res(
    input_dir = 'data/gtab_res/victim/original/',
    output_data_path = 'data/processed/victim_list_01252023.xlsx',
    write = True,
    adjust_method = 'mean'
)

df_victim_mean
# Out:
#                   victim  victim_id   2016_01   2016_02   2016_03   2016_04  \
# 0       Debbie Schlussel          1  0.005263  0.013158  0.013158  0.000000
# 1       Caroline Heldman          2  0.000000  0.005376  0.002688  0.005376
# 2    Scottie Nell Hughes          3  0.012500  0.034375  0.046875  0.312500
# 3          Jasmine Baker          4  0.004651  0.002584  0.006783  0.005491
# 4        Eden Rohatensky          5  0.000775  0.001938  0.001615  0.006783
# ..                   ...        ...       ...       ...       ...       ...
# 190     Michelle Herrera        191  0.006202  0.011305  0.013243  0.009044
# 191       Naomi R. Shatz        192       NaN       NaN       NaN       NaN
# 192           Dana Loewy        193  0.000669  0.000000  0.000598  0.000000
# 193                 Heil        194  1.118519  1.143519  1.180556  1.050926
# 194       Nicole Eastman        195  0.002008  0.001434  0.002032  0.001195
#
# ...
